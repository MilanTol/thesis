# %%
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams.update({
    "font.size": 16,          # base font size
    "axes.labelsize": 18,     # x and y labels
    "axes.titlesize": 18,     # title
    "legend.fontsize": 14,    # legend
    "xtick.labelsize": 14,    # x tick labels
    "ytick.labelsize": 14,    # y tick labels
})

import sys
import os
import copy

sys.path.append(os.path.abspath("/home/milan/Desktop/thesis/code"))

# %%
from halo_model.power_spectra.param_effect import param_effect_spectrum
from halo_model.config.config import Config

sys.path.append(os.path.abspath("/home/milan/Desktop/thesis/code/plotting_code/gas_profile")) 

cfg = Config()

# %%
fig1 = param_effect_spectrum(cfg, 'theta_ej', cfg.theta_ej + 2)
# Out:
# interpolating Ic and Jc functions...
# interpolating Ic and Jc functions...

# %%
fig2 = param_effect_spectrum(cfg, 'logM_gaslimit', cfg.logM_gaslimit + 1)
# Out:
# interpolating Ic and Jc functions...
# Process ForkPoolWorker-501:
# Process ForkPoolWorker-511:
# Process ForkPoolWorker-502:
# Process ForkPoolWorker-507:
# Process ForkPoolWorker-500:
# Process ForkPoolWorker-508:
# Process ForkPoolWorker-503:
# Process ForkPoolWorker-499:
# Process ForkPoolWorker-510:
# Process ForkPoolWorker-509:
# Process ForkPoolWorker-504:
# Process ForkPoolWorker-505:
# Process ForkPoolWorker-506:
# Process ForkPoolWorker-512:
# Traceback (most recent call last):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 fig2 = param_effect_spectrum(cfg, 'logM_gaslimit', cfg.logM_gaslimit + 2)
#
# File ~/Desktop/thesis/code/halo_model/power_spectra/param_effect.py:83, in param_effect_spectrum(cfg, param, val)
#      80 cfg_mod = copy.deepcopy(cfg)
#      81 setattr(cfg_mod, param, val)
# ---> 83 Pm = compute_Pk(cfg)
#      84 Pm_mod = compute_Pk(cfg_mod)
#      86 return Pm_mod['P_tot']/Pm['P_tot']
#
# File ~/Desktop/thesis/code/halo_model/power_spectra/param_effect.py:60, in compute_Pk(cfg)
#      57 # compute CDM power spectrum
#      58 clump_mass_func = ClumpMassGiocoli2010_mod(cfg_local)
# ---> 60 Pm = MatterPowerBaryons(cfg_local,
#      61                 mass_func=mass_func,
#      62                 shmr=shmr,
#      63                 shmr_central=shmr_central,
#      64                 smooth_profile_dm=smooth_profile_dm,
#      65                 stellar_profile=stellar_profile,
#      66                 gas_profile=gas_profile,
#      67                 bias=bias,
#      68                 clump_mass_func=clump_mass_func,
#      69                 clump_profile_dm=clump_profile_dm,
#      70                 clump_distribution=clump_distribution)
#      72 # instantiate storage arrays
#      73 k_grid = np.geomspace(cfg.k_min, cfg.k_max, cfg.N_k)
#
# File ~/Desktop/thesis/code/halo_model/power_spectra/matter_power_baryons.py:103, in MatterPowerBaryons.__init__(self, cfg, mass_func, shmr, shmr_central, smooth_profile_dm, stellar_profile, gas_profile, bias, clump_mass_func, clump_profile_dm, clump_distribution)
#     100 args = [(np.log(cfg.m_min), lnM, cfg.N_m, self, np.exp(lnk), np.exp(lnM)) for lnk in lnk_grid for lnM in lnM_grid]
#     102 with Pool(processes=cpu_count()) as pool:
# --> 103     points = pool.map(compute_point, args)
#     105 # Fill results into arrays
#     106 for (k, M, Ic_val, Jc_val) in points:
#
# File /usr/lib/python3.10/multiprocessing/pool.py:367, in Pool.map(self, func, iterable, chunksize)
#     362 def map(self, func, iterable, chunksize=None):
#     363     '''
#     364     Apply `func` to each element in `iterable`, collecting the results
#     365     in a list that is returned.
#     366     '''
# --> 367     return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File /usr/lib/python3.10/multiprocessing/pool.py:768, in ApplyResult.get(self, timeout)
#     767 def get(self, timeout=None):
# --> 768     self.wait(timeout)
#     769     if not self.ready():
#     770         raise TimeoutError
#
# File /usr/lib/python3.10/multiprocessing/pool.py:765, in ApplyResult.wait(self, timeout)
#     764 def wait(self, timeout=None):
# --> 765     self._event.wait(timeout)
#
# File /usr/lib/python3.10/threading.py:607, in Event.wait(self, timeout)
#     605 signaled = self._flag
#     606 if not signaled:
# --> 607     signaled = self._cond.wait(timeout)
#     608 return signaled
#
# File /usr/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %%
fig3 = param_effect_spectrum(cfg, 'beta', cfg.beta - 0.5)

# %%
fig4 = param_effect_spectrum(cfg, 'S', cfg.S - 0.02)
# Out:
# interpolating Ic and Jc functions...
# interpolating Ic and Jc functions...

# %%
k_grid = np.geomspace(cfg.k_min, cfg.k_max, cfg.N_k)

fig = plt.figure(figsize=(6,5))
plt.plot(k_grid, fig1, label=r'$\theta_\mathrm{eject}$')
# plt.plot(k_grid, fig2, label=r'$\log_{10}M_\mathrm{gaslimit}$')
plt.plot(k_grid, fig3, label=r'$\beta$')
plt.plot(k_grid, fig4, label=r'$f_\star$')
plt.xlim(1e-1, 1e4)
plt.ylim(0.935, 1.005)
plt.xscale('log')
plt.legend()
plt.ylabel(r'$P_{m, \rm mod}(k) / P_m(k)$')
plt.xlabel(r'$k \; h/\mathrm{Mpc}$')
plt.show()
